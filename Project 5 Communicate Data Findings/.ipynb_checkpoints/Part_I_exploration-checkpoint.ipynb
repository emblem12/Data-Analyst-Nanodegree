# %% [markdown]
# # Part I - FIFA22-Soccer
# ## by Jamil Abdulai
#
# ## Introduction
# > FIFA is a soccer video game produced by EA which has gained notoriety among individuals from all-around the world with over 31 million players on FIFA 22. A new FIFA game comes out every year in which EA rates all the players in the game and give them certain stats which are supposed to be a depiction of real life. Each player is rated on various attributes which are then used to give them an overall score. Some of the attributes players are rated on include stats such as: Pace, Dribbling, Shooting. Our group was curious, if we take these values as accurate, what can we learn about the real world?
#
# > The main target for this analysis are real soccer players as well as soccer fanatics. Real soccer players will benefit the most from our analysis. If I was soccer player, I would be looking to learn which attribute of my self I can boost the most to not only improve my self as a player but to also improve my salary. I hope that our analysis could help players direct their workout regiment by helping understand which attributes are truly considered valuable in soccer and for a club. Soccer fanatics will also benefit from our analysis as it will help them better understand which characteristics they may want to look for when looking at potential trade prospects for their respective team.
#
# > The dataset is in a two part .csv files, 'players_fifa22.csv' and 'teams_fifa22.csv'. The intention is to analyze the 'players_fifa22.csv' file for this project.
# Access to dataset : https://www.kaggle.com/datasets/bryanb/fifa-player-stats-database
#
#
#
# ## Preliminary Wrangling

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

# %% [markdown]
# > Load in your dataset and describe its properties through the questions below. Try and motivate your exploration goals through this section.

# %%
#Load the dataset
soccer_fifa_22 = pd.read_csv('players_fifa22.csv')
soccer_fifa_22.head()
# Out:
#        ID               Name                      FullName  Age  Height  \
# 0  158023           L. Messi                  Lionel Messi   34     170
# 1  188545     R. Lewandowski            Robert Lewandowski   32     185
# 2   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro   36     187
# 3  231747          K. Mbappé                 Kylian Mbappé   22     182
# 4  200389           J. Oblak                     Jan Oblak   28     188
#
#    Weight                                          PhotoUrl Nationality  \
# 0      72  https://cdn.sofifa.com/players/158/023/22_60.png   Argentina
# 1      81  https://cdn.sofifa.com/players/188/545/22_60.png      Poland
# 2      83  https://cdn.sofifa.com/players/020/801/22_60.png    Portugal
# 3      73  https://cdn.sofifa.com/players/231/747/22_60.png      France
# 4      87  https://cdn.sofifa.com/players/200/389/22_60.png    Slovenia
#
#    Overall  Potential  ...  LMRating  CMRating  RMRating LWBRating CDMRating  \
# ...

# %% [markdown]
# ### Assessing the dataset

# %% [markdown]
# #### Removing unwanted columns

# %%
#Number of rows and columns
soccer_fifa_22.shape
# Out:
# (19260, 90)

# %%
#Quick overview of the dataset
soccer_fifa_22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19260 entries, 0 to 19259
# Data columns (total 90 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 19260 non-null  int64
#  1   Name               19260 non-null  object
#  2   FullName           19260 non-null  object
#  3   Age                19260 non-null  int64
#  4   Height             19260 non-null  int64
#  5   Weight             19260 non-null  int64
#  6   PhotoUrl           19260 non-null  object
#  7   Nationality        19260 non-null  object
#  8   Overall            19260 non-null  int64
#  9   Potential          19260 non-null  int64
#  10  Growth             19260 non-null  int64
#  11  TotalStats         19260 non-null  int64
#  12  BaseStats          19260 non-null  int64
#  13  Positions          19260 non-null  object
#  14  BestPosition       19260 non-null  object
#  15  Club               19260 non-null  object
# ...

# %% [markdown]
# ### Data Cleaning

# %%
#Delete unused columns for analysis.
soccer_fifa_22.drop(['Positions','NationalTeam' ,'Name', 'PhotoUrl', 'OnLoad', 'NationalPosition', 'NationalNumber'], axis = 1, inplace = True)

# %%
#Delete more unused columns
soccer_fifa_22.drop(soccer_fifa_22.columns[61:89], axis = 1, inplace = True)

# %%
#Observe dropped columns
soccer_fifa_22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19260 entries, 0 to 19259
# Data columns (total 61 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 19260 non-null  int64
#  1   FullName           19260 non-null  object
#  2   Age                19260 non-null  int64
#  3   Height             19260 non-null  int64
#  4   Weight             19260 non-null  int64
#  5   Nationality        19260 non-null  object
#  6   Overall            19260 non-null  int64
#  7   Potential          19260 non-null  int64
#  8   Growth             19260 non-null  int64
#  9   TotalStats         19260 non-null  int64
#  10  BaseStats          19260 non-null  int64
#  11  BestPosition       19260 non-null  object
#  12  Club               19260 non-null  object
#  13  ValueEUR           19260 non-null  int64
#  14  WageEUR            19260 non-null  int64
#  15  ReleaseClause      19260 non-null  int64
# ...

# %%
#Observe if there are any duplicated values
soccer_fifa_22.duplicated().sum()
# Out:
# 104

# %%
#Drop duplicates
soccer_fifa_22.drop_duplicates(inplace = True)

# %%
#Confirm drop
soccer_fifa_22.duplicated().sum()
# Out:
# 0

# %%
#Observe all null values
soccer_fifa_22.isnull().sum()
# Out:
# ID                0
# FullName          0
# Age               0
# Height            0
# Weight            0
#                  ..
# Penalties         0
# Composure         0
# Marking           0
# StandingTackle    0
# SlidingTackle     0
# Length: 61, dtype: int64

# %%
#Drop all rows with null values
soccer_fifa_22.dropna(axis = 0, inplace = True)

# %%
soccer_fifa_22.shape
# Out:
# (19080, 61)

# %% [markdown]
# #### Fixing datatypes

# %%
# Observe the datatypes
soccer_fifa_22.dtypes
# Out:
# ID                 int64
# FullName          object
# Age                int64
# Height             int64
# Weight             int64
#                    ...
# Penalties          int64
# Composure          int64
# Marking            int64
# StandingTackle     int64
# SlidingTackle      int64
# Length: 61, dtype: object

# %%
soccer_fifa_22.head(10)
# Out:
#        ID                      FullName  Age  Height  Weight Nationality  \
# 0  158023                  Lionel Messi   34     170      72   Argentina
# 1  188545            Robert Lewandowski   32     185      81      Poland
# 2   20801  C. Ronaldo dos Santos Aveiro   36     187      83    Portugal
# 3  231747                 Kylian Mbappé   22     182      73      France
# 4  200389                     Jan Oblak   28     188      87    Slovenia
# 5  192985               Kevin De Bruyne   30     181      70     Belgium
# 6  190871    Neymar da Silva Santos Jr.   29     175      68      Brazil
# 7  215914                  N'Golo Kanté   30     168      70      France
# 8  202126                    Harry Kane   27     188      89     England
# 9  192448         Marc-André ter Stegen   29     187      85     Germany
#
#    Overall  Potential  Growth  TotalStats  ...  LongShots Aggression  \
# 0       93         93       0        2219  ...         94         44
# ...

# %%
#Descriptive statistics
print(soccer_fifa_22.describe())
# Out:
#                   ID           Age        Height        Weight       Overall  \
# count   19080.000000  19080.000000  19080.000000  19080.000000  19080.000000
# mean   231667.419759     25.182180    181.293396     74.941981     65.758019
# std     27005.549109      4.740406      6.864329      7.062326      6.804072
# min        41.000000     16.000000    155.000000     49.000000     48.000000
# 25%    214775.000000     21.000000    176.000000     70.000000     61.000000
# 50%    236676.000000     25.000000    181.000000     75.000000     66.000000
# 75%    253682.750000     29.000000    186.000000     80.000000     70.000000
# max    264705.000000     54.000000    206.000000    110.000000     93.000000
#
#           Potential        Growth    TotalStats     BaseStats      ValueEUR  \
# count  19080.000000  19080.000000  19080.000000  19080.000000  1.908000e+04
# mean      71.050000      5.291981   1597.247222    356.783595  2.837032e+06
# ...

# %%
print(soccer_fifa_22['WageEUR'].describe())
# Out:
# count     19080.000000
# mean       8929.777254
# std       19438.404790
# min         500.000000
# 25%        1000.000000
# 50%        3000.000000
# 75%        8000.000000
# max      350000.000000
# Name: WageEUR, dtype: float64

# %% [markdown]
# ### Insights:
# 1. From the descriptive analysis of the dataset, the average wage in Euros is 8,973.53 out of 19,260 players. The minimum was 0 with a maximum of 350,0000 Euros weekly.Also, 75%f the players averages 8,000.00 Euros compared to a median of 3,000 Euros.
#
# 2. With respect to the age, the oldest player is 54 years old whereas the youngest was 16 years of age. Furthermore, 75% of the players are 29 years compared to a median of 25 out of 19,260 players.
#
# 3. Likely, the tallest players is 206cm compared to the shortest recorded as 155cm with a median and 75% recorded as 186cm and 181cm respectively.
#
# 4. The player with the highest value in Euros is 194,000,000.00 compared to the lowest value of 0.

# %% [markdown]
# ### What is the structure of your dataset?
#
# > The above dataset was initially composed of 19260 rows and 90 columns prior to wrangling. Unwanted columns were dropped as well as null values to enhance the overall objective of the analysis. The data has both categorical and quantitative data which will absolutely enhance the visualization processes.
#
# ### What is/are the main feature(s) of interest in your dataset?
#
# > The primary focus will be on the characteristics of the players and their ability to either perform. Emphasis will be placed on what separates the best from the rest. Factors like age, nationality, overall, poential, club, value, wages, position, body type, work rate, international reputation, preferred foot, ball control and agility will be analyzed.
#
# ### What features in the dataset do you think will help support your investigation into your feature(s) of interest?
#
# > Characteristics like wage, age, weight, height and weight will have massive implications on the analysis.

# %% [markdown]
# ## Univariate Exploration

# %% [markdown]
# ### Quantitative Statistical Analysis of Data

# %%
#Define all the labels for the visualization
def label(x,y,t):
    """
    Args:
      x(str): label of x-axis
      y(str): label of y-axis
      t(str): label of title
    
    Returns: 
      None
    """
    plt.xlabel(x)
    plt.ylabel(y)
    plt.title()

# %%
#Histogram Distribution Growth of Players
sb.distplot(soccer_fifa_22['Growth'], color = '#2f3640') 

g.fig.set_size_inches(14, 8);
plt.xlabel('Growth')
plt.ylabel('Frequency')
plt.title('Distribution Growth of Players')
# Out:
# C:\Users\reart\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Distribution Growth of Players')

# %% [markdown]
# From the analysis, the visualization is right skewed/ positive skewed which means that the peak of the graph lies to the left side of the center. On the right side of the graph, the frequencies of observations are lower than the frequencies of observations to the left side.

# %%
#Histogram Distribution Potential of Players
sb.distplot(soccer_fifa_22['Potential'], color = '#0fb9b1') 

plt.xlabel('Potential')
plt.ylabel('Frequency')
plt.title('Distribution Potential of Players')
# Out:
# C:\Users\reart\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Distribution Potential of Players')

# %% [markdown]
# From the analysis, the distribution is bell-shaped/normall dsitribution hence the mode, mean and median are all centrally aligned with most potential within the 70s.

# %%
#Histogram Distribution Age of Players
sb.distplot(soccer_fifa_22['Age'], color = '#192a56') 

plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Distribution Age of Players')
# Out:
# C:\Users\reart\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Distribution Age of Players')

# %% [markdown]
# From the visualization, the graph is slightly positively skewed, thus have a slight right tail with majority of the players between 20-30 years.

# %%
#Histogram Distribution Weight of Players
sb.distplot(soccer_fifa_22['Weight'], color = '#4cd137')

plt.xlabel('Weight')
plt.ylabel('Frequency')
plt.title('Distribution Weight of Players')
# Out:
# C:\Users\reart\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Distribution Weight of Players')

# %% [markdown]
# The visualization optimized a normal distribution with average weight between 70-80kg

# %%
#Histogram Distribution Height of Players
sb.distplot(soccer_fifa_22['Height'], color = '#e84118') 

# Add labels
plt.xlabel('Height')
plt.ylabel('Frequency')
plt.title('Distribution Height of Players')
# Out:
# C:\Users\reart\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Distribution Height of Players')

# %% [markdown]
# Also, this graph had a normal distribution with the average height of 180cm

# %% [markdown]
# ### Visualizations of categorical variables

# %% [markdown]
# #### The top 10  Natioanlity of Players

# %%
#A bar graph of the top 10 Nationalities 
nationality = soccer_fifa_22.Nationality.value_counts()[0:10]

#Plot
nationality_graph = nationality.plot.bar(color = '#0c2461', fontsize = 12)


#Add labels
plt.xlabel('Country')
plt.ylabel('Number of occurrence')
plt.title('Top Players Nationalities')
# Out:
# Text(0.5, 1.0, 'Top Players Nationalities')

# %% [markdown]
# From the analysis, the countries with the most clubs are England, Germany, Spain, France, Argentina, Brazil, Japan, Netherlands, United States and Poland. 5 out of the top 10 clubs reside in European clountries followed by 3 countries from South America and lastly, 1 from Asia and North America respectively.

# %% [markdown]
# #### A graph of Top 25 Most Popular Clubs

# %%
#A bar graph of the top 25 Nationalities 
player_club = soccer_fifa_22.Club.value_counts()[0:25]

#Plot
club_graph = player_club.plot.bar(color = '#0c2461', fontsize = 12)

#Add labels
plt.xlabel('Club')
plt.ylabel('Number of occurrence')
plt.title('Top 25 Most Popular Clubs')
# Out:
# Text(0.5, 1.0, 'Top 25 Most Popular Clubs')

# %% [markdown]
# There are multiple soccer clubs across the globe. From the analysis, any soccer fanatic will attest to the fact that his/her club is among the top 30 clubs on the list. From the Real Madrid, FC Barcelona, Paris Saint-Germain, Manchester United, Manchester City, Arsenal, Chelsea and Tottenham Hotspur just to mention a few with all from Europe.

# %% [markdown]
# #### Most Popular Playing Positions

# %%
#Player Position
best_position = soccer_fifa_22['BestPosition'].value_counts()
player_position_order = best_position.index

# %%
#Plot the graph
ax = plt.subplots(1,1, figsize=(7,7))


base_color = sb.color_palette()[0]
sb.countplot(data = soccer_fifa_22, y = 'BestPosition', color = '#0c2461', order = best_position.index)
plt.ylabel('Position', color = 'black')
plt.xlabel('Frequency', color = 'black');
plt.title('The Most Popular Playing Position' )
# Out:
# Text(0.5, 1.0, 'The Most Popular Playing Position')

# %% [markdown]
# From the analysis, the most popular playing positions are CB-Center Back, ST-Striker, CAM-Central Attacking Midfielder, GK-Goalkeeper, RM-Right Midfield, CDM-Central Defensive Midfielder with the rest of the other positions not mostly favored by the players.

# %% [markdown]
# #### The preferred foot of player

# %%
#Plot the graph
soccer_fifa_22['PreferredFoot'].value_counts().plot.bar( color = '#0c2461')
                                                       
plt.ylabel('Count')
plt.xlabel('Foot')
plt.title('Preferred Foot Type');

# %% [markdown]
# The visualization clearly shows that more than 50% of the soccer players are predominantly right-footed.

# %% [markdown]
# ### Discuss the distribution(s) of your variable(s) of interest. Were there any unusual points? Did you need to perform any transformations?
#
# Quantitative Statistical Analysis of Data
#
# >1.  A histogram distribution of the growth of players were analyzed. From the analysis, the visualization is right skewed/ positive skewed which means that the peak of the graph lies to the left side of the center. On the right side of the graph, the frequencies of observations are lower than the frequencies of observations to the left side.
# 2. Also, a histogram distribution of the potential of players was analyzed. From the analysis, the distribution is bell-shaped/normall dsitribution hence the mode, mean and median are all centrally aligned with most potential within the 70s.
# 3. Furthermore, a visual histogram presentation of the ages indicated that, majority of the players are within the ages of 20-30 years.
# 4. In addition, when the distribution of the weight-class was analyzed, it was adamant that the most players weighed between 70-80kg.
# 5. Lastly, the visual distribution of the heights of the players reinterates that majority of them were bewteen 175-180cm.
#
# Visualizations of categorical variables
# > 1. The top 10 nationalities of the players were analyzed with majority originating from England followed by Germany, Spain, France, Argentina and Brazil.
# 2. Also, a graph of the Top 25 most popular clubs indicated that all the countries stemmed from the continent of Europe like Paris Saint-Germain, FC Barcelona, Real Madrid CF, Manchester City and Arsenal just to mention few.
# 3. The analysis of the most preferred position show that majority of the players preferred CB-Center Back, ST-Striker, CAM-Central Attacking Midfielder, GK-Goalkeeper, RM-Right Midfield, CDM-Central Defensive Midfielder with the rest of the other positions not mostly favored by the players.
# 4. Lastly, the analization of the preferred foot of players clearly indicates that more than 50% of the soccer players are predominantly right-footed
#
#
# ### Of the features you investigated, were there any unusual distributions? Did you perform any operations on the data to tidy, adjust, or change the form of the data? If so, why did you do this?
#
# > Upon analysis, I came across multiple columns with similar meaning or data like 'Name' and 'FullName' hence I deleted it.Also, the 'Positions' and 'BestPositions' columns provided similar information hence the Positions columns was eliminated.Columns like 'PhotoUrl', 'OnLoad', 'NationalPosition' and'NationalNumber' were all deleted because it was irrelevant for the anlysis.
# Lastly, the statiscal histogram distribution of growth took me aback after the plot due to majority of the players showing a '0' growth but after further investigation, I noticed it made sense because the comparison of the overall performance of those players with respect to previous yeay(YoY) were the same.

# %% [markdown]
# ## Bivariate Exploration

# %% [markdown]
# ### Correlations of the Data

# %% [markdown]
# #### Scatter Plots

# %%
#The correlation of Strength vs Stamina
soccer_fifa_22.plot(x = 'Strength', y = 'Stamina', kind = 'scatter', title = 'Strength vs Stamina', alpha = 0.2);

# %% [markdown]
# This visualization shows a very week correlation between the strength and stamina. This is a bit shocking because I expected players with strength should have stamina.

# %%
#The correlation of SlidingTackle vs StandingTackle
soccer_fifa_22.plot(x = 'SlidingTackle', y = 'StandingTackle', kind = 'scatter', title = 'SlidingTackle vs StandingTackle',alpha=0.2);

# %% [markdown]
# The analysis indicates a strong positive relationship between a sliding and standing tackle, thus, most players who are likely to defend standing will do similar sliding.

# %%
#The correlation of Finishing vs Aggression
soccer_fifa_22.plot(x = 'Finishing', y = 'Aggression', kind = 'scatter', title = 'Finishing vs Aggression', alpha=0.2);

# %% [markdown]
# The visuals indicates that there is no correlation between finishing and aggression. The players can convert the chances to goal but doesn't have to necessarily be aggressive.

# %%
#The correlation of Attacking vs Defensive Work Rate
soccer_fifa_22.plot(x = 'AttackingWorkRate', y = 'DefensiveWorkRate', kind = 'scatter', title = 'Attacking vs Defensive Work Rate', alpha=0.2);

# %% [markdown]
# The analyses is pretty intriguing. The attacking and defensive work rates are completely non-realtional. This is due to the  playing positions of the players. The Strikers ST, and Midfielders are responsible for majority of the attacking workrate with respect to the Center Backs CB and Midfielders reponsible for the defensive workrate.

# %%
#The correlation of Shooting Total vs Passing Total
soccer_fifa_22.plot(x = 'ShootingTotal', y = 'PassingTotal', kind = 'scatter', title = 'Shooting Total vs Passing Total', alpha=0.2);

# %% [markdown]
# The analysis confirms a weak postivie relationship between shooting toal and passing total thus there is slight chances of players who pass the ball are also likely to shoot it as well.

# %%
#The correlation of Defending Total vs Physicality Total
soccer_fifa_22.plot(x = 'DefendingTotal', y = 'PhysicalityTotal', kind = 'scatter', title = 'Defending Total vs Physicality Total', alpha=0.2);

# %% [markdown]
# The graph indicates a very weak correlation of defending vs physicality total. The majority of the people who defend are somewhat likely to be physical or strong.

# %% [markdown]
# #### Violin Plots

# %%
#Violin plot preferred foot vs weak foot rating
ax = plt.subplots(1,1, figsize=(8,8))


sb.violinplot(data = soccer_fifa_22, x = 'PreferredFoot', y = 'WeakFoot', 
             color = '#0be881',
              inner = 'quartile')
plt.ylabel('Weak Foot Rating')
plt.xlabel('Preferred Foot')
plt.title('Plot of preferred foot vs weak foot rating');

# %% [markdown]
# The graph shows that irrespective of the weak foot used, both show a rating of 3.

# %%
#Violin plot of Defensive Work Rate to Value 
ax = plt.subplots(1,1, figsize=(8,8))


sb.violinplot(data = soccer_fifa_22, x = 'DefensiveWorkRate', y = 'ValueEUR', 
             color = '#0be881',
              inner = 'quartile')
plt.ylabel('Value of Player')
plt.xlabel('Defensive Work Rate')
plt.title('Plot of Defensive Work Rate to Value');

# %% [markdown]
# The graph is interesting. Players with low defensive work rates are values more.

# %%
#Violin plot of Attacking Work Rate to Value 
ax = plt.subplots(1,1, figsize=(8,8))


sb.violinplot(data = soccer_fifa_22, x = 'AttackingWorkRate', y = 'ValueEUR', 
             color = '#0be881',
              inner = 'quartile')
plt.ylabel('Value of Player')
plt.xlabel('Attacking Work Rate')
plt.title('Plot of Attacking Work Rate to Value');

# %% [markdown]
# The visulization depicts that players with high attacking work rates are valued more.

# %%
#Violin plot of BestPosition Work Rate to Wage 
ax = plt.subplots(1,1, figsize=(8,8))


sb.violinplot(data = soccer_fifa_22, x = 'BestPosition', y = 'WageEUR', 
             color = '#0be881',
              inner = 'quartile')
plt.ylabel('Wage of Player')
plt.xlabel('Best Position')
plt.title('Plot of Best Position Work Rate to Wage');

# %% [markdown]
# The analysis is adamant that the players with the most wages are CF-Center Forwards.

# %% [markdown]
# #### Heat Map

# %%
soccer_fifa_22_hist = soccer_fifa_22[['Age', 'Overall', 'Potential', 'ValueEUR', 'WageEUR', 'Height', 'Weight', 'Finishing', 'HeadingAccuracy', 
                     'Acceleration','SprintSpeed','Stamina','Strength','Penalties','PaceTotal', 'Strength', 'Jumping', 'Interceptions']]

# plotting heatmap
f, ax = plt.subplots(figsize=(8, 8))
corr = soccer_fifa_22_hist.corr()
sb.heatmap(corr, cmap = 'crest',
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)
plt.ylabel('soccer attributes')
plt.xlabel('soccer attributes')
plt.title('Heat Map of All Values');

# %% [markdown]
# From the analysis:
# 1. Pace total has a positive correlation with weight and height
# 2. Jumping has a positive correlation with jumping abilities
# 3. Height and weight have negative correlation with acceleration and sprint
# 4. Heading accuracy have a negative correlation with height and weight
# 5. Ptential have negative correlation with age.
# 6. Penalties have positive correlation with finishing

# %% [markdown]
# #### Bar graphs visualization

# %%
#Group by Club then sum the value.
player_rating_country = soccer_fifa_22.groupby('Club')['ValueEUR'].sum().sort_values(ascending = False).head(5)

#Plot the graph
player_rating_country.plot.bar(color = '#EA2027' )
plt.ylabel('Frequency')
plt.xlabel('Club')
plt.title('The Top 5 Most Expensive Players');

# %% [markdown]
# The analysis indicates that the top 5 clubs with the most value are Manchester City, Paris Saint-Germain, Liverpool, Manchester United and Real Madrid CF.

# %%
#Group by nationality then sum the value.
player_rating_country = soccer_fifa_22.groupby('Nationality')['Overall'].sum().sort_values(ascending = False).head(5)

#Plot the graph
player_rating_country.plot.bar(color = '#EA2027' )
plt.ylabel('Frequency')
plt.xlabel('Country')
plt.title('The Top 5 Countries With Most Rated Players');

# %% [markdown]
# The plot predicts that the top 5 countries with the most rated players are England, which is the highes, followed by Germany, Spain, France and Argentina.

# %%
#Group by nationality then sum the value.
player_rating_country = soccer_fifa_22.groupby('Nationality')['ValueEUR'].sum().sort_values(ascending = False).head(5)

#Plot the graph
player_rating_country.plot.bar(color = '#EA2027' )
plt.ylabel('Frequency')
plt.xlabel('Country')
plt.title('The 5 Countries With Most Expensive Players');

# %% [markdown]
# The graph shows that the players with the most value come from Spain, Francem Brazil, England and Germany

# %%
#Group by FullName then sum the value.
player_rating_country = soccer_fifa_22.groupby('FullName')['WageEUR'].sum().sort_values(ascending = False).head(5)

#Plot the graph
player_rating_country.plot.bar(color = '#EA2027' )
plt.ylabel('Frequency')
plt.xlabel('Player')
plt.title('The Top 5 Most Paid Players');

# %% [markdown]
# Karim Benzema had the most earnings followed by Kevin De Bryne, Lionel Messi, Casemiro and lastly, Toni Kroos.

# %%
#Group by FullName then sum the value.
player_rating_country = soccer_fifa_22.groupby('FullName')['ValueEUR'].sum().sort_values(ascending = False).head(5)

#Plot the graph
player_rating_country.plot.bar(color = '#EA2027' )
plt.ylabel('Frequency')
plt.xlabel('Player')
plt.title('The Top 5 Most Expensive Players')
# Out:
# Text(0.5, 1.0, 'The Top 5 Most Expensive Players')

# %% [markdown]
# The graph shows Kylian Mbappe, Erling Haaland, Harry Kanr, Neymar and Kevin De Bruyne are the most expensise players to purchase.

# %%
#Group by Club then sum the value.
player_rating_country = soccer_fifa_22.groupby('Club')['WageEUR'].sum().sort_values(ascending = False).head(5)

#Plot the graph
player_rating_country.plot.bar(color = '#EA2027' )
plt.ylabel('Frequency')
plt.xlabel('Club')
plt.title('  The Top 5 Clubs With Most Wages Earned by Players');

# %% [markdown]
# The analysis emphasis that Real Madrid paid their players the most followed by Manchester City. Manchester United, FC Barcelona and Liverpool were the bottom 3 of 5.

# %% [markdown]
# #### Histogram distribution

# %%
#Plot Facet
bins = np.arange(12, 58+2, 2)
g = sb.FacetGrid(data = soccer_fifa_22, col = 'DefensiveWorkRate')
g.map(plt.hist, 'Age', bins = bins);

# %% [markdown]
# The distribution of age with defensive work rate indicates that majority of the players  have a medium defensive work rate.

# %%
#Plot Facet
bins = np.arange(12, 58+2, 2)
g = sb.FacetGrid(data = soccer_fifa_22, col = 'AttackingWorkRate')
g.map(plt.hist, 'Age', bins = bins);

# %% [markdown]
# Likewise, this analysis indicates majority of the players have a medium ofensive work rate.

# %% [markdown]
# ### Talk about some of the relationships you observed in this part of the investigation. How did the feature(s) of interest vary with other features in the dataset?
#
# >1.  The visualization of scatter plot of Stength vs Stamina shows a very week correlation between the strength and stamina. This is a bit shocking because I expected players with strength should have stamina.
# 2. Also, The analysis of SLiding Tackles vs Standing Tackles indicate a strong positive relationship between a sliding and standing tackle, thus, most players who are likely to defend standing will do similar sliding.
# 3. Furthermore, The analysis of Shooting Total vs Passing Total confirms a weak postivie relationship between shooting toal and passing total thus there is slight chances of players who pass the ball are also likely to shoot it as well.
# 4. The bar graph of the top 5 clubs with expensive players indicates that clubs with the most value are Manchester City, Paris Saint-Germain, Liverpool, Manchester United and Real Madrid CF.
# 5. Karim Benzema had the most earnings followed by Kevin De Bryne, Lionel Messi, Casemiro and lastly, Toni Kroos.
# 6. Kylian Mbappe, Erling Haaland, Harry Kane, Neymar and Kevin De Bruyne are the most expensise players to purchase.
# 7. The violin graph shows players with low defensive and high attacking work rates are values more, players with the most wages are CF-Center Forward.
# 8. Lastly, the histogram of the distribution of age with defensive work rate indicates that majority of the players have a medium defensive and offensive work rate.
# ### Did you observe any interesting relationships between the other features (not the main feature(s) of interest)?
#
# > About the heat map, I'm intrigued why Height have a negative correspondence to finishing. I believe there are multiple ways of scoring a goal and height shouldn't be a primary factor.

# %% [markdown]
# ## Multivariate Exploration

# %%
#Plot Facet
g = sb.FacetGrid(data = soccer_fifa_22, hue = 'DefensiveWorkRate', size = 6, aspect = 1.5, palette = 'tab10')
g.map(plt.scatter, 'Agility', 'Balance', )
plt.xlabel('Agility')
plt.ylabel('Balance')
plt.title('Plot of Agility and Balance Over Defensive Work Rate')
g.add_legend()
# Out:
# C:\Users\reart\anaconda3\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# The graph shows a positive correlation between agility and balance attributes with respect to defensive work rate. Majority of the defensive work rate is medium and occurs at the bottom with a high press around the mid-section of the graph.

# %%
#Plot Facet
g = sb.FacetGrid(data = soccer_fifa_22, hue = 'AttackingWorkRate', size = 6, aspect = 1.5, palette = 'tab10')
g.map(plt.scatter, 'Agility', 'Balance')
plt.xlabel('Agility')
plt.ylabel('Balance')
plt.title('Plot of Agility and Balance Over Attacking Work Rate')
g.add_legend()
# Out:
# C:\Users\reart\anaconda3\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# The graph shows a positive correlation between agility and balance attributes with respect to attacking work rate. Most of the attacking work rate is medium and occurs at the bottom with a high press around the mid-section of the graph.

# %%
#Plot facet
g = sb.FacetGrid(data = soccer_fifa_22, col = 'BallControl', col_wrap = 3, size = 3)
g.map(plt.scatter, 'Vision', 'Composure');
# Out:
# C:\Users\reart\anaconda3\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# The analysis depicts that with respect to vision and composure, majority of the ball composure occurred between 52 and 79 times on the field. This means mos of the soccer players were able to hold unto the ball witnin those constraints.

# %%
#Plotting matrices 

player_statistic = ['LongShots' ,'Positioning','Marking']

g = sb.PairGrid(data = soccer_fifa_22, vars = player_statistic);
g.map_offdiag(plt.scatter);
g.map_diag(plt.hist);

# %% [markdown]
# This analysis depicts the relationships between Longshot, Positioning, and Marking among themselves.Most of the graphs are weakly positive hence showing correlations

# %%
age_acceleration = ['SkillMoves', 'Age']

#Plot Heatmap 
sb.heatmap(soccer_fifa_22[age_acceleration].corr(), cmap = 'crest', annot = True, fmt = '.2f')
plt.ylabel('Plot of Skill Move and Age')
plt.xlabel('Plot of Skill Move and Age')
plt.title('Heat Map of All Values');

# %% [markdown]
# Players who are older have high skill moves compared to younger ones with less skill moves.

# %% [markdown]
# ### Talk about some of the relationships you observed in this part of the investigation. Were there features that strengthened each other in terms of looking at your feature(s) of interest?
#
# > After a further analysis was conducted, there was a positive correlation between agility and balance attributes with respect to defensive work rate. Majority of the defensive work rate is medium and occurs at the bottom with a high press around the mid-section of the graph. Also, the further analysis depicts that with respect to vision and composure, majority of the ball composure occurred between 52 and 79 times on the field. This means mos of the soccer players were able to hold unto the ball witnin those constraints. Furthermore, from the heatmap, players who are older have high skill moves compared to younger ones with less skill moves.
#
# ### Were there any interesting or surprising interactions between features?
#
# > All the analysis and features made sense in the course of the analysis.
